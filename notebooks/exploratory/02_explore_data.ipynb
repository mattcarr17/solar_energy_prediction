# %% [markdown]
# # Exploratory Notebook
#
# This notebook will contain initial exploration of the data as well as cleaning and formatting. All data used in this notebook can be found in the data directory. The energy data is found in the data/solar_output directory and weather data in data/weather.

# %%
# Import libraries
import os
import pandas as pd
import numpy as np

# %% [markdown]
# Since the energy data was scraped on a daily time frame, I have to read in multiple files into a single dataframe. Below I will create a list of all files from data/solar_output directory to be stored in the energy dataframe.

# %%
filelist = os.listdir('./../data/solar_output')

# %%
file_list[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3b08fa863eb6> in <module>
# ----> 1 file_list[0]
#
# NameError: name 'file_list' is not defined

# %% [markdown]
# Now that I have all the files stored in the list, I need to add the path to the data directory before I can read these files into a dataframe. I need to add the path to each file name. I will store that in a seperate list, 'fl', which I can utilize to store the files in a dataframe

# %%
fl = ['../data/solar_output/' + str(f) for f in filelist]

# %% [markdown]
# Now that I have all of the files stored in a list with their respective path's, I can use these files to create a list of dataframes, which I can then concatenate into a single dataframe.

# %%
df_list = [pd.read_csv(f) for f in fl]

# %%
big_df = pd.concat(df_list)

# %%
big_df.head()
# Out:
#            Unnamed: 0 University of Illinois Unnamed: 2
# 0           Timestamp   New Nexus 1272 Meter  Inverters
# 1                 NaN                     kW         kW
# 2  3/12/2018 12:00 AM                  -8.14        NaN
# 3  3/12/2018 12:15 AM                  -9.14        NaN
# 4  3/12/2018 12:30 AM                  -9.31        NaN

# %%
big_df.columns = ['time', 'nexus_meter', 'inverter']

# %%
big_df.drop([0,1], axis=0, inplace=True)

# %%
big_df['time'] = pd.to_datetime(big_df['time'])

# %%
energy_df = big_df.sort_values('time')

# %%
energy_df.head()
# Out:
#                  time nexus_meter inverter
# 2 2017-12-12 00:00:00         NaN      NaN
# 3 2017-12-12 00:15:00         NaN      NaN
# 4 2017-12-12 00:30:00         NaN      NaN
# 5 2017-12-12 00:45:00         NaN      NaN
# 6 2017-12-12 01:00:00         NaN      NaN

# %%
energy_df2 = energy_df.set_index('time')

# %%
hourly = energy_df2.resample('H').sum()

# %%
hourly.tail()
# Out:
#                               nexus_meter        inverter
# time
# 2020-07-20 19:00:00           2.52175e+10     2.77199e+11
# 2020-07-20 20:00:00    30.2-0.503-15.7-14  52.718.80.0390
# 2020-07-20 21:00:00  -13.7-13.6-13.6-13.6            0000
# 2020-07-20 22:00:00  -13.5-13.6-13.7-13.8            0000
# 2020-07-20 23:00:00  -13.7-13.7-13.7-13.7            0000

# %%
energy_df3 = energy_df2[['nexus_meter', 'inverter']].astype(float)

# %%
hourly = energy_df3.resample('H').sum()

# %%
hourly.shape
# Out:
# (22848, 2)

# %%
hourly[:'2018-01-30 15:00:00']
# Out:
#                      nexus_meter  inverter
# time
# 2017-12-12 00:00:00          0.0       0.0
# 2017-12-12 01:00:00          0.0       0.0
# 2017-12-12 02:00:00          0.0       0.0
# 2017-12-12 03:00:00          0.0       0.0
# 2017-12-12 04:00:00          0.0       0.0
# ...                          ...       ...
# 2018-01-30 11:00:00      10128.0   10162.0
# 2018-01-30 12:00:00      17570.0   17734.0
# 2018-01-30 13:00:00      16156.0   16323.0
# 2018-01-30 14:00:00      12779.0   12901.0
# 2018-01-30 15:00:00       6430.0    6528.0
#
# [1192 rows x 2 columns]

# %%
hourly = hourly['2018-01-30':]

# %%
hourly.head(15)
# Out:
#                      nexus_meter  inverter
# time
# 2018-01-30 00:00:00          0.0      0.00
# 2018-01-30 01:00:00          0.0      0.00
# 2018-01-30 02:00:00          0.0      0.00
# 2018-01-30 03:00:00          0.0      0.00
# 2018-01-30 04:00:00          0.0      0.00
# 2018-01-30 05:00:00          0.0      0.00
# 2018-01-30 06:00:00          0.0      1.08
# 2018-01-30 07:00:00          0.0     57.50
# 2018-01-30 08:00:00          0.0      0.00
# 2018-01-30 09:00:00          0.0      0.00
# 2018-01-30 10:00:00        276.6    321.00
# 2018-01-30 11:00:00      10128.0  10162.00
# 2018-01-30 12:00:00      17570.0  17734.00
# 2018-01-30 13:00:00      16156.0  16323.00
# 2018-01-30 14:00:00      12779.0  12901.00

# %% [markdown]
# Great now I have all of my energy data stored in a single dataframe. I will need to do some additional cleaning (night time hours have no energy production). But for now, I want to move on to getting my weather data set up and formatted. I will start by reading in the weatherstation2.csv file from data/weather directory and storing it in a dataframe

# %%
weather = pd.read_csv('../data/weather/weatherstation2.csv')

# %% [markdown]
# Next i convert the 'DATE' column to a pandas datetime object. This will allow me to resample and structure the time increments as needed.

# %%
weather['DATE'] = pd.to_datetime(weather['DATE'])

# %%
weather.head()
# Out:
#        STATION                DATE REPORT_TYPE  SOURCE  AWND  BackupDirection  \
# 0  72531594870 2018-01-29 00:23:00       FM-16       7   NaN              NaN
# 1  72531594870 2018-01-29 00:42:00       FM-16       7   NaN              NaN
# 2  72531594870 2018-01-29 00:51:00       FM-16       6   NaN              NaN
# 3  72531594870 2018-01-29 00:53:00       FM-15       7   NaN              NaN
# 4  72531594870 2018-01-29 01:53:00       FM-15       7   NaN              NaN
#
#    BackupDistance  BackupDistanceUnit  BackupElements  BackupElevation  ...  \
# 0             NaN                 NaN             NaN              NaN  ...
# 1             NaN                 NaN             NaN              NaN  ...
# 2             NaN                 NaN             NaN              NaN  ...
# 3             NaN                 NaN             NaN              NaN  ...
# 4             NaN                 NaN             NaN              NaN  ...
#
#    ShortDurationPrecipitationValue060  ShortDurationPrecipitationValue080  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    ShortDurationPrecipitationValue100  ShortDurationPrecipitationValue120  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    ShortDurationPrecipitationValue150  ShortDurationPrecipitationValue180  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    Sunrise  Sunset  TStorms WindEquipmentChangeDate
# 0      NaN     NaN      NaN              2007-05-10
# 1      NaN     NaN      NaN              2007-05-10
# 2      NaN     NaN      NaN              2007-05-10
# 3      NaN     NaN      NaN              2007-05-10
# 4      NaN     NaN      NaN              2007-05-10
#
# [5 rows x 124 columns]

# %% [markdown]
# Next I set the index of the weather dataframe as "DATE" so I can use it for time series analysis. I store this dataframe in weather_df

# %%
weather_df = weather.set_index('DATE')

# %%
weather_df.head()
# Out:
#                          STATION REPORT_TYPE  SOURCE  AWND  BackupDirection  \
# DATE
# 2018-01-29 00:23:00  72531594870       FM-16       7   NaN              NaN
# 2018-01-29 00:42:00  72531594870       FM-16       7   NaN              NaN
# 2018-01-29 00:51:00  72531594870       FM-16       6   NaN              NaN
# 2018-01-29 00:53:00  72531594870       FM-15       7   NaN              NaN
# 2018-01-29 01:53:00  72531594870       FM-15       7   NaN              NaN
#
#                      BackupDistance  BackupDistanceUnit  BackupElements  \
# DATE
# 2018-01-29 00:23:00             NaN                 NaN             NaN
# 2018-01-29 00:42:00             NaN                 NaN             NaN
# 2018-01-29 00:51:00             NaN                 NaN             NaN
# 2018-01-29 00:53:00             NaN                 NaN             NaN
# 2018-01-29 01:53:00             NaN                 NaN             NaN
#
#                      BackupElevation  BackupElevationUnit  ...  \
# DATE                                                       ...
# 2018-01-29 00:23:00              NaN                  NaN  ...
# 2018-01-29 00:42:00              NaN                  NaN  ...
# 2018-01-29 00:51:00              NaN                  NaN  ...
# 2018-01-29 00:53:00              NaN                  NaN  ...
# 2018-01-29 01:53:00              NaN                  NaN  ...
#
#                      ShortDurationPrecipitationValue060  \
# DATE
# 2018-01-29 00:23:00                                 NaN
# 2018-01-29 00:42:00                                 NaN
# 2018-01-29 00:51:00                                 NaN
# 2018-01-29 00:53:00                                 NaN
# 2018-01-29 01:53:00                                 NaN
#
#                      ShortDurationPrecipitationValue080  \
# DATE
# 2018-01-29 00:23:00                                 NaN
# 2018-01-29 00:42:00                                 NaN
# 2018-01-29 00:51:00                                 NaN
# 2018-01-29 00:53:00                                 NaN
# 2018-01-29 01:53:00                                 NaN
#
#                      ShortDurationPrecipitationValue100  \
# DATE
# 2018-01-29 00:23:00                                 NaN
# 2018-01-29 00:42:00                                 NaN
# 2018-01-29 00:51:00                                 NaN
# 2018-01-29 00:53:00                                 NaN
# 2018-01-29 01:53:00                                 NaN
#
#                      ShortDurationPrecipitationValue120  \
# DATE
# 2018-01-29 00:23:00                                 NaN
# 2018-01-29 00:42:00                                 NaN
# 2018-01-29 00:51:00                                 NaN
# 2018-01-29 00:53:00                                 NaN
# 2018-01-29 01:53:00                                 NaN
#
#                      ShortDurationPrecipitationValue150  \
# DATE
# 2018-01-29 00:23:00                                 NaN
# 2018-01-29 00:42:00                                 NaN
# 2018-01-29 00:51:00                                 NaN
# 2018-01-29 00:53:00                                 NaN
# 2018-01-29 01:53:00                                 NaN
#
#                      ShortDurationPrecipitationValue180  Sunrise  Sunset  \
# DATE
# 2018-01-29 00:23:00                                 NaN      NaN     NaN
# 2018-01-29 00:42:00                                 NaN      NaN     NaN
# 2018-01-29 00:51:00                                 NaN      NaN     NaN
# 2018-01-29 00:53:00                                 NaN      NaN     NaN
# 2018-01-29 01:53:00                                 NaN      NaN     NaN
#
#                     TStorms  WindEquipmentChangeDate
# DATE
# 2018-01-29 00:23:00     NaN               2007-05-10
# 2018-01-29 00:42:00     NaN               2007-05-10
# 2018-01-29 00:51:00     NaN               2007-05-10
# 2018-01-29 00:53:00     NaN               2007-05-10
# 2018-01-29 01:53:00     NaN               2007-05-10
#
# [5 rows x 123 columns]

# %% [markdown]
# There are only a few columns in the dataframe that actually contain data and therefore are the only ones that are useful for my analysis. I gathered the names of those columns from the dataframe and store the column names in 'weather_cols'. I will then use this list to subset the dataframe to contain only the features useful.

# %%
weather_cols = ['REPORT_TYPE', 'SOURCE', 'HourlyAltimeterSetting', 'HourlyDewPointTemperature', 'HourlyDryBulbTemperature', 'HourlyPrecipitation', 'HourlyRelativeHumidity',
'HourlySeaLevelPressure', 'HourlySkyConditions', 'HourlyStationPressure', 'HourlyVisibility', 'HourlyWetBulbTemperature', 'HourlyWindDirection', 'HourlyWindSpeed', 'REM']

# %%
weather_df = weather_df[weather_cols]

# %%
weather_df.head()
# Out:
#                     REPORT_TYPE  SOURCE HourlyAltimeterSetting  \
# DATE
# 2018-01-29 00:23:00       FM-16       7                  30.34
# 2018-01-29 00:42:00       FM-16       7                  30.35
# 2018-01-29 00:51:00       FM-16       6                  30.34
# 2018-01-29 00:53:00       FM-15       7                  30.34
# 2018-01-29 01:53:00       FM-15       7                  30.34
#
#                     HourlyDewPointTemperature HourlyDryBulbTemperature  \
# DATE
# 2018-01-29 00:23:00                        28                       30
# 2018-01-29 00:42:00                        28                       30
# 2018-01-29 00:51:00                        28                       30
# 2018-01-29 00:53:00                        28                       30
# 2018-01-29 01:53:00                        28                       30
#
#                     HourlyPrecipitation HourlyRelativeHumidity  \
# DATE
# 2018-01-29 00:23:00                 NaN                     92
# 2018-01-29 00:42:00                 NaN                     92
# 2018-01-29 00:51:00                 NaN                     93
# 2018-01-29 00:53:00                0.00                     92
# 2018-01-29 01:53:00                   T                     92
#
#                     HourlySeaLevelPressure            HourlySkyConditions  \
# DATE
# 2018-01-29 00:23:00                    NaN             SCT:04 8 OVC:08 75
# 2018-01-29 00:42:00                    NaN  BKN:07 10 BKN:07 70 OVC:08 80
# 2018-01-29 00:51:00                    NaN                       OVC:08 9
# 2018-01-29 00:53:00                  30.36                       OVC:08 9
# 2018-01-29 01:53:00                  30.35                       OVC:08 9
#
#                     HourlyStationPressure HourlyVisibility  \
# DATE
# 2018-01-29 00:23:00                 29.51             5.00
# 2018-01-29 00:42:00                 29.52             6.00
# 2018-01-29 00:51:00                 29.51             6.00
# 2018-01-29 00:53:00                 29.51             6.00
# 2018-01-29 01:53:00                 29.51             3.00
#
#                     HourlyWetBulbTemperature HourlyWindDirection  \
# DATE
# 2018-01-29 00:23:00                       29                 330
# 2018-01-29 00:42:00                       29                 320
# 2018-01-29 00:51:00                       29                 330
# 2018-01-29 00:53:00                       29                 330
# 2018-01-29 01:53:00                       29                 340
#
#                     HourlyWindSpeed  \
# DATE
# 2018-01-29 00:23:00              14
# 2018-01-29 00:42:00              13
# 2018-01-29 00:51:00              15
# 2018-01-29 00:53:00              15
# 2018-01-29 01:53:00              10
#
#                                                                    REM
# DATE
# 2018-01-29 00:23:00  MET09701/29/18 00:23:02 SPECI KCMI 290623Z 330...
# 2018-01-29 00:42:00  MET10401/29/18 00:42:02 SPECI KCMI 290642Z 320...
# 2018-01-29 00:51:00  MET08501/29/18 00:51:02 SPECI KCMI 290651Z 330...
# 2018-01-29 00:53:00  MET09701/29/18 00:53:02 METAR KCMI 290653Z 330...
# 2018-01-29 01:53:00  MET11301/29/18 01:53:02 METAR KCMI 290753Z 340...

# %% [markdown]
# Now I have all of the columns I want in a dataframe. Now I can check for missing values and begin exploring the data.

# %%
weather_df.isna().sum()
# Out:
# REPORT_TYPE                     0
# SOURCE                          0
# HourlyAltimeterSetting        939
# HourlyDewPointTemperature    1015
# HourlyDryBulbTemperature      934
# HourlyPrecipitation          5714
# HourlyRelativeHumidity       1015
# HourlySeaLevelPressure       8449
# HourlySkyConditions          1018
# HourlyStationPressure        1026
# HourlyVisibility              937
# HourlyWetBulbTemperature     1102
# HourlyWindDirection          1017
# HourlyWindSpeed              1019
# REM                             0
# dtype: int64

# %%
weather_df.dtypes
# Out:
# REPORT_TYPE                  object
# SOURCE                        int64
# HourlyAltimeterSetting       object
# HourlyDewPointTemperature    object
# HourlyDryBulbTemperature     object
# HourlyPrecipitation          object
# HourlyRelativeHumidity       object
# HourlySeaLevelPressure       object
# HourlySkyConditions          object
# HourlyStationPressure        object
# HourlyVisibility             object
# HourlyWetBulbTemperature     object
# HourlyWindDirection          object
# HourlyWindSpeed              object
# REM                          object
# dtype: object

# %% [markdown]
# Even though the majority of columns primarily have numeric values, all of the columns (excluding source) are stored as object. The reason for this is there are a few strings located in this columns throughout the dataframe.

# %%
weather_df['HourlyPrecipitation'].value_counts()
# Out:
# 0.00     18638
# T         2788
# 0.01       804
# 0.02       409
# 0.03       259
#          ...
# 0.87         1
# 0.82s        1
# 1.09         1
# 0.81         1
# 0.94         1
# Name: HourlyPrecipitation, Length: 113, dtype: int64

# %% [markdown]
# You can see an example above. The hourly precipitation is usally a numeric value, however the string 'T' is scattered throughout the values. This indicates "trace amounts of precipitation". The values are in inches of precipitation in the given time period. I think it is safe to assume that "trace amounts" could be categorized as no precipitation (value of 0). So I am going to go through and all values of 'T' will be replaced with 0. I also see that a few values have an 's' tagged onto the end. There is no discussion of this in the data documentation, so I am going to assume these are typos and I will remove 's' from any observations it is present in.

# %%
weather_df['HourlyPrecipitation'] = ['0.00' if val == 'T' else val for val in weather_df['HourlyPrecipitation']]

# %%
weather_df['HourlyPrecipitation'].value_counts()
# Out:
# 0.00     21426
# 0.01       804
# 0.02       409
# 0.03       259
# 0.04       200
#          ...
# 0.87         1
# 0.82s        1
# 1.09         1
# 0.81         1
# 0.94         1
# Name: HourlyPrecipitation, Length: 112, dtype: int64

# %% [markdown]
# Now all values of 'T' are stored as 0. Now I want to remove 's' from any values it is present in.

# %%
weather_df['HourlyPrecipitation'].value_counts()
# Out:
# 0.00     21426
# 0.01       804
# 0.02       409
# 0.03       259
# 0.04       200
#          ...
# 0.87         1
# 0.82s        1
# 1.09         1
# 0.81         1
# 0.94         1
# Name: HourlyPrecipitation, Length: 112, dtype: int64

# %%
precip = []
for val in weather_df['HourlyPrecipitation'].values:
    if 's' in str(val):
        precip.append(val.replace('s', ''))
    else:
        precip.append(val)

# %%
weather_df['HourlyPrecipitation'] = precip

# %%
weather_df['HourlyPrecipitation'].value_counts()
# Out:
# 0.00    21426
# 0.01      807
# 0.02      412
# 0.03      266
# 0.04      200
#         ...
# 0.78        1
# 2.13        1
# 0.62        1
# 0.80        1
# 0.56        1
# Name: HourlyPrecipitation, Length: 96, dtype: int64

# %% [markdown]
# Great now all of the 's' occurences are removed. Before I can fill in the missing values I need to explore and format the other values as I did this one. So I will go through each column and make sure all values make sense and are in the same format

# %%
weather_df['HourlyAltimeterSetting'].value_counts()
# Out:
# 29.99    585
# 29.98    551
# 29.97    541
# 30.02    540
# 29.96    537
#         ...
# 30.85      1
# 29.31      1
# 30.79      1
# 29.47      1
# 30.7       1
# Name: HourlyAltimeterSetting, Length: 287, dtype: int64

# %% [markdown]
# Similar to the precipitation data, 'HourlyAltimeterSetting' also has 's' in a few of it's values. I will do the same thing as before and remove the 's' from all values it is present in.

# %%
altmeter = []
for val in weather_df['HourlyAltimeterSetting'].values:
    if 's' in str(val):
        altmeter.append(val.replace('s', ''))
    else:
        altmeter.append(val)

# %%
weather_df['HourlyAltimeterSetting'] = altmeter

# %%
weather_df['HourlyAltimeterSetting'].value_counts()
# Out:
# 29.99    585
# 29.98    551
# 29.97    541
# 30.02    540
# 29.96    537
#         ...
# 30.85      1
# 30.72      1
# 30.7       1
# 29.47      1
# 30.76      1
# Name: HourlyAltimeterSetting, Length: 284, dtype: int64

# %% [markdown]
# 'HourlyAltimeterSetting' is now formatted properly. Next I will look at 'HourlyDewPointTemperature'

# %%
weather_df['HourlyDewPointTemperature'].value_counts()
# Out:
# 70       503
# 32.0     491
# 30.0     491
# 31.0     452
# 28.0     450
#         ...
# -8.0       1
# -13.0      1
# 79.0       1
# -18.0      1
# -26.0      1
# Name: HourlyDewPointTemperature, Length: 199, dtype: int64

# %% [markdown]
# This column seems to be alright, so I will leave it for now and fix it if a problem occurs later on.

# %%
weather_df['HourlyDryBulbTemperature'].value_counts()
# Out:
# 32     797
# 33     687
# 34     643
# 70     638
# 31     627
#       ...
# 44s      1
# -16      1
# 68s      1
# 96       1
# 20s      1
# Name: HourlyDryBulbTemperature, Length: 122, dtype: int64

# %% [markdown]
# Once again 's' is present in some values, so I need to take care of that. Instead of continuosly writing a for loop to do this, I am going to write a function that takes care of this for me.

# %%
def remove_s(df, col):
    lst = []
    for val in df[col].values:
        if 's' in str(val):
            lst.append(val.replace('s', ''))
        else:
            lst.append(val)
    return lst

# %%
weather_df['HourlyDryBulbTemperature'] = remove_s(weather_df, 'HourlyDryBulbTemperature')

# %%
weather_df['HourlyDryBulbTemperature'].value_counts()
# Out:
# 32     797
# 33     687
# 34     643
# 70     640
# 31     633
#       ...
# -11      2
# -16      1
# -14      1
# 97       1
# 96       1
# Name: HourlyDryBulbTemperature, Length: 114, dtype: int64

# %% [markdown]
# Function works as planned, now I can use that for similar occurences.

# %%
weather_df['HourlyRelativeHumidity'].value_counts()
# Out:
# 100      1712
# 100.0    1561
# 96.0     1392
# 93.0     1195
# 96       1004
#          ...
# 15          2
# 17.0        2
# 21.0        1
# 19.0        1
# 16.0        1
# Name: HourlyRelativeHumidity, Length: 168, dtype: int64

# %% [markdown]
# This one seems to be okay. Instead of going through each column individually, I am going to create a loop that goes through and find's if 's' is present in any of the values of a given column, if it is, it add's the column name to a list.

# %%
columns_with_s = []
for col in weather_cols:
    values = weather_df[col].value_counts().index
    for value in values:
        if 's' in values:
            columns_with_s.append(col)

# %%
columns_with_s
# Out:
# []

# %% [markdown]
# That list turned out empty so i think it is safe to assume that the rest of the columns don't have this problem. There are a few other irregular occurences I need to take care of however. For example, the '*' symbol seems to be present in a few columns. So I need to take care of that. The documentation says that this value means that "Amounts included in following measurement; time distribution unknown". I believe this means that this measurement is simply added to the next time index. If this is the case, I could simply drop these columns, but I need to be sure about this.

# %%
weather_df[weather_df['HourlyWetBulbTemperature'] == '*']
# Out:
#                     REPORT_TYPE  SOURCE HourlyAltimeterSetting  \
# DATE
# 2018-03-28 10:53:00       FM-15       7                  29.96
# 2020-06-23 11:53:00       FM-15       7                  29.85
# 2020-06-24 11:58:00       FM-15       7                  29.93
#
#                     HourlyDewPointTemperature HourlyDryBulbTemperature  \
# DATE
# 2018-03-28 10:53:00                         *                        *
# 2020-06-23 11:53:00                         *                        *
# 2020-06-24 11:58:00                         *                        *
#
#                     HourlyPrecipitation HourlyRelativeHumidity  \
# DATE
# 2018-03-28 10:53:00                0.00                      *
# 2020-06-23 11:53:00                0.00                      *
# 2020-06-24 11:58:00                0.00                      *
#
#                     HourlySeaLevelPressure  HourlySkyConditions  \
# DATE
# 2018-03-28 10:53:00                    NaN             OVC:08 8
# 2020-06-23 11:53:00                    NaN            FEW:02 45
# 2020-06-24 11:58:00                    NaN  FEW:02 49 SCT:04 65
#
#                     HourlyStationPressure HourlyVisibility  \
# DATE
# 2018-03-28 10:53:00                 29.14             5.00
# 2020-06-23 11:53:00                 29.03            10.00
# 2020-06-24 11:58:00                 29.11            10.00
#
#                     HourlyWetBulbTemperature HourlyWindDirection  \
# DATE
# 2018-03-28 10:53:00                        *                 060
# 2020-06-23 11:53:00                        *                 310
# 2020-06-24 11:58:00                        *                 000
#
#                     HourlyWindSpeed  \
# DATE
# 2018-03-28 10:53:00               5
# 2020-06-23 11:53:00              17
# 2020-06-24 11:58:00               0
#
#                                                                    REM
# DATE
# 2018-03-28 10:53:00  MET09203/28/18 10:53:02 METAR KCMI 281653Z 060...
# 2020-06-23 11:53:00  MET07206/23/20 11:53:02 METAR KCMI 231753Z 310...
# 2020-06-24 11:58:00  MET07906/24/20 11:58:02 METAR KCMI 241758Z 000...

# %% [markdown]
# So there are only four columns that ever contain the value '*' and they are all for the same time indices. I am going to return to this problem shortly. Now I want to focus on the 'HourlySkyConditions' column which is pretty much the only true categorical column. I need to do one of two things. I can either summarize these values as one of four cloud coverage values (clear, slightly cloudy, partly cloudy, overcast) or I can make the value numeric as percentage of sky covered. I am going to start with the latter and try and calculate the cloud coverage as a percentage.

# %% [markdown]
# The 'HourlySkyConditions' column contains nan values which are stored as floats, the other values are stored as strings. The documentation says there can be up to three cloud layers included in this column. When trying to get the overall cloud coverage and multiple cloud layers are listed, it says to use the last one. The format of the column is as follows (coverage code: amount of 'oktas', and cloud base height). I want the amount of oktas for the last value of each observation, this gives amount of sky covered by clouds and can be used to calculate cloud coverage percentage.

# %%
clouds = []
for val in weather_df['HourlySkyConditions'].values:
    if type(val) == float:
        clouds.append(val)
    elif type(val) == str:
        v = val.split()
        if len(v) == 1:
            clouds.append(int(v[0][-1]))
        elif len(v) > 1:
            try:
                clouds.append(int(v[-2][-1]))
            except:
                clouds.append(int(v[-1][-1]))

# %%
cloud_percent = [v if v==np.nan else ((v/10) * 100) for v in clouds]

# %%
weather_df['cloud_coverage'] = cloud_percent

# %%
weather_df.head(5)
# Out:
#                     REPORT_TYPE  SOURCE HourlyAltimeterSetting  \
# DATE
# 2018-01-29 00:23:00       FM-16       7                  30.34
# 2018-01-29 00:42:00       FM-16       7                  30.35
# 2018-01-29 00:51:00       FM-16       6                  30.34
# 2018-01-29 00:53:00       FM-15       7                  30.34
# 2018-01-29 01:53:00       FM-15       7                  30.34
#
#                     HourlyDewPointTemperature HourlyDryBulbTemperature  \
# DATE
# 2018-01-29 00:23:00                        28                       30
# 2018-01-29 00:42:00                        28                       30
# 2018-01-29 00:51:00                        28                       30
# 2018-01-29 00:53:00                        28                       30
# 2018-01-29 01:53:00                        28                       30
#
#                     HourlyPrecipitation HourlyRelativeHumidity  \
# DATE
# 2018-01-29 00:23:00                 NaN                     92
# 2018-01-29 00:42:00                 NaN                     92
# 2018-01-29 00:51:00                 NaN                     93
# 2018-01-29 00:53:00                0.00                     92
# 2018-01-29 01:53:00                0.00                     92
#
#                     HourlySeaLevelPressure            HourlySkyConditions  \
# DATE
# 2018-01-29 00:23:00                    NaN             SCT:04 8 OVC:08 75
# 2018-01-29 00:42:00                    NaN  BKN:07 10 BKN:07 70 OVC:08 80
# 2018-01-29 00:51:00                    NaN                       OVC:08 9
# 2018-01-29 00:53:00                  30.36                       OVC:08 9
# 2018-01-29 01:53:00                  30.35                       OVC:08 9
#
#                     HourlyStationPressure HourlyVisibility  \
# DATE
# 2018-01-29 00:23:00                 29.51             5.00
# 2018-01-29 00:42:00                 29.52             6.00
# 2018-01-29 00:51:00                 29.51             6.00
# 2018-01-29 00:53:00                 29.51             6.00
# 2018-01-29 01:53:00                 29.51             3.00
#
#                     HourlyWetBulbTemperature HourlyWindDirection  \
# DATE
# 2018-01-29 00:23:00                       29                 330
# 2018-01-29 00:42:00                       29                 320
# 2018-01-29 00:51:00                       29                 330
# 2018-01-29 00:53:00                       29                 330
# 2018-01-29 01:53:00                       29                 340
#
#                     HourlyWindSpeed  \
# DATE
# 2018-01-29 00:23:00              14
# 2018-01-29 00:42:00              13
# 2018-01-29 00:51:00              15
# 2018-01-29 00:53:00              15
# 2018-01-29 01:53:00              10
#
#                                                                    REM  \
# DATE
# 2018-01-29 00:23:00  MET09701/29/18 00:23:02 SPECI KCMI 290623Z 330...
# 2018-01-29 00:42:00  MET10401/29/18 00:42:02 SPECI KCMI 290642Z 320...
# 2018-01-29 00:51:00  MET08501/29/18 00:51:02 SPECI KCMI 290651Z 330...
# 2018-01-29 00:53:00  MET09701/29/18 00:53:02 METAR KCMI 290653Z 330...
# 2018-01-29 01:53:00  MET11301/29/18 01:53:02 METAR KCMI 290753Z 340...
#
#                      cloud_coverage
# DATE
# 2018-01-29 00:23:00            80.0
# 2018-01-29 00:42:00            80.0
# 2018-01-29 00:51:00            80.0
# 2018-01-29 00:53:00            80.0
# 2018-01-29 01:53:00            80.0

# %% [markdown]
# Now that I have cloud coverage calculated, I can select the columns that actually give information.

# %%
w_cols = ['HourlyAltimeterSetting', 'HourlyDewPointTemperature', 'HourlyDryBulbTemperature', 'HourlyRelativeHumidity', 'HourlySeaLevelPressure',
'HourlyStationPressure', 'HourlyVisibility', 'HourlyWetBulbTemperature', 'HourlyWindSpeed', 'cloud_coverage']

# %%
w_df = weather_df[w_cols]

# %%
w_df.head()
# Out:
#                     HourlyAltimeterSetting HourlyDewPointTemperature  \
# DATE
# 2018-01-29 00:23:00                  30.34                        28
# 2018-01-29 00:42:00                  30.35                        28
# 2018-01-29 00:51:00                  30.34                        28
# 2018-01-29 00:53:00                  30.34                        28
# 2018-01-29 01:53:00                  30.34                        28
#
#                     HourlyDryBulbTemperature HourlyRelativeHumidity  \
# DATE
# 2018-01-29 00:23:00                       30                     92
# 2018-01-29 00:42:00                       30                     92
# 2018-01-29 00:51:00                       30                     93
# 2018-01-29 00:53:00                       30                     92
# 2018-01-29 01:53:00                       30                     92
#
#                     HourlySeaLevelPressure HourlyStationPressure  \
# DATE
# 2018-01-29 00:23:00                    NaN                 29.51
# 2018-01-29 00:42:00                    NaN                 29.52
# 2018-01-29 00:51:00                    NaN                 29.51
# 2018-01-29 00:53:00                  30.36                 29.51
# 2018-01-29 01:53:00                  30.35                 29.51
#
#                     HourlyVisibility HourlyWetBulbTemperature HourlyWindSpeed  \
# DATE
# 2018-01-29 00:23:00             5.00                       29              14
# 2018-01-29 00:42:00             6.00                       29              13
# 2018-01-29 00:51:00             6.00                       29              15
# 2018-01-29 00:53:00             6.00                       29              15
# 2018-01-29 01:53:00             3.00                       29              10
#
#                      cloud_coverage
# DATE
# 2018-01-29 00:23:00            80.0
# 2018-01-29 00:42:00            80.0
# 2018-01-29 00:51:00            80.0
# 2018-01-29 00:53:00            80.0
# 2018-01-29 01:53:00            80.0

# %% [markdown]
# Okay there are still two problems I need to address: missing values and the time index frequency. After talking with one of my instructors, these are both things I need to experiment with and see what gives me the best results for my models. For now however, just until I get an MVP done, I am going to average all observations within a given hour and see if I still need to impute any missing values from there. First I need to convert all column types to numeric. For the time being I am also going to drop the rows that have a '*' for any values.

# %%
to_drop = weather_df[weather_df['HourlyRelativeHumidity'] == '*'].index

# %%
w_df.drop(to_drop, axis=0, inplace=True)

# %% [markdown]
# Now that that is taken care of, I can covert all of the columns to numeric. This will allow me to group together the rows into hourly observations.

# %%
for col in w_cols:
    try:
        w_df[col] = w_df[col].astype(float)
    except:
        print(col)
# Out:
# HourlySeaLevelPressure
# HourlyStationPressure
# HourlyVisibility
# HourlyWindSpeed

# %% [markdown]
# So the five columns above still have 's' in some of their values. After I take care of that I should be able to convert them to numeric.

# %%
w_df['HourlySeaLevelPressure'] = remove_s(w_df, 'HourlySeaLevelPressure')
w_df['HourlyStationPressure'] = remove_s(w_df, 'HourlyStationPressure')
w_df['HourlyVisibility'] = remove_s(w_df, 'HourlyVisibility')
w_df['HourlyWindSpeed'] = remove_s(w_df, 'HourlyWindSpeed')

# %%
for col in w_cols:
    try:
        w_df[col] = w_df[col].astype(float)
    except:
        print(col)
# Out:
# HourlyVisibility

# %% [markdown]
# These two seem to have a "V" in a few of the values, I am going to rewrite the function from earlier, this time allowing the value to be removed to be passed in as an argument.

# %%
def remove_value(df, col, value):
    lst = []
    for val in df[col].values:
        if value in str(val):
            lst.append(val.replace(value, ''))
        else:
            lst.append(val)
    return lst

# %%
w_df['HourlyVisibility'] = remove_value(w_df, 'HourlyVisibility', 'V')

# %%
for col in w_cols:
    try:
        w_df[col] = w_df[col].astype(float)
    except:
        print(col)
# Out:
# HourlyVisibility

# %% [markdown]
# It seems 'HourlyVisibility' also has some '*' values. I will drop those from w_df now

# %%
to_drop2 = w_df[w_df['HourlyVisibility'] == '*'].index

# %%
w_df.drop(to_drop2, axis=0, inplace=True)

# %%
for col in w_cols:
    w_df[col] = w_df[col].astype(float)

# %%
w_df.dtypes
# Out:
# HourlyAltimeterSetting       float64
# HourlyDewPointTemperature    float64
# HourlyDryBulbTemperature     float64
# HourlyRelativeHumidity       float64
# HourlySeaLevelPressure       float64
# HourlyStationPressure        float64
# HourlyVisibility             float64
# HourlyWetBulbTemperature     float64
# HourlyWindSpeed              float64
# cloud_coverage               float64
# dtype: object

# %% [markdown]
# Now I can aggregate the indices for one hour taking the mean of all observations within that hour.

# %%
weather_hourly = w_df.resample('H').mean()

# %%
weather_hourly.isna().sum()
# Out:
# HourlyAltimeterSetting        14
# HourlyDewPointTemperature     58
# HourlyDryBulbTemperature      13
# HourlyRelativeHumidity        58
# HourlySeaLevelPressure        24
# HourlyStationPressure         71
# HourlyVisibility              14
# HourlyWetBulbTemperature     110
# HourlyWindSpeed               76
# cloud_coverage                72
# dtype: int64

# %% [markdown]
# I was hoping that would take care of the missing values but some are still present. That means that there were some hours were no observations were reported. I want to see the time frames this was occuring, if it was occuring at hours where no energy would be generated (night), I am going to ignore those values anyways so it shouldn't be a problem.

# %%
df = pd.concat([hourly, weather_hourly], axis=1)

# %%
df.tail(10)
# Out:
#                      nexus_meter   inverter  HourlyAltimeterSetting  \
# DATE
# 2020-07-20 14:00:00    13269.000  13560.000                   30.01
# 2020-07-20 15:00:00    12480.000  12718.000                   30.01
# 2020-07-20 16:00:00     8412.000   8516.000                   30.00
# 2020-07-20 17:00:00     7061.000   7246.000                   29.99
# 2020-07-20 18:00:00     2684.000   2797.000                   29.99
# 2020-07-20 19:00:00      625.100    723.000                   30.01
# 2020-07-20 20:00:00       -0.003     71.539                   30.02
# 2020-07-20 21:00:00      -54.500      0.000                   30.04
# 2020-07-20 22:00:00      -54.600      0.000                   30.04
# 2020-07-20 23:00:00      -54.800      0.000                   30.02
#
#                      HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# DATE
# 2020-07-20 14:00:00                       69.0                      84.0
# 2020-07-20 15:00:00                       67.0                      83.0
# 2020-07-20 16:00:00                       67.0                      83.0
# 2020-07-20 17:00:00                       68.0                      79.0
# 2020-07-20 18:00:00                       67.0                      78.0
# 2020-07-20 19:00:00                       68.0                      75.0
# 2020-07-20 20:00:00                       69.0                      73.0
# 2020-07-20 21:00:00                       69.0                      72.0
# 2020-07-20 22:00:00                       68.0                      71.0
# 2020-07-20 23:00:00                       68.0                      71.0
#
#                      HourlyRelativeHumidity  HourlySeaLevelPressure  \
# DATE
# 2020-07-20 14:00:00                    61.0                   29.99
# 2020-07-20 15:00:00                    59.0                   29.99
# 2020-07-20 16:00:00                    59.0                   29.98
# 2020-07-20 17:00:00                    69.0                   29.97
# 2020-07-20 18:00:00                    69.0                   29.98
# 2020-07-20 19:00:00                    79.0                   29.99
# 2020-07-20 20:00:00                    87.0                   30.00
# 2020-07-20 21:00:00                    91.0                   30.02
# 2020-07-20 22:00:00                    90.0                   30.02
# 2020-07-20 23:00:00                    90.0                   30.00
#
#                      HourlyStationPressure  HourlyVisibility  \
# DATE
# 2020-07-20 14:00:00                  29.19              10.0
# 2020-07-20 15:00:00                  29.19              10.0
# 2020-07-20 16:00:00                  29.18              10.0
# 2020-07-20 17:00:00                  29.17              10.0
# 2020-07-20 18:00:00                  29.17              10.0
# 2020-07-20 19:00:00                  29.19              10.0
# 2020-07-20 20:00:00                  29.20              10.0
# 2020-07-20 21:00:00                  29.22              10.0
# 2020-07-20 22:00:00                  29.22              10.0
# 2020-07-20 23:00:00                  29.20              10.0
#
#                      HourlyWetBulbTemperature  HourlyWindSpeed  cloud_coverage
# DATE
# 2020-07-20 14:00:00                      74.0              7.0            20.0
# 2020-07-20 15:00:00                      72.0              0.0             0.0
# 2020-07-20 16:00:00                      72.0              6.0             0.0
# 2020-07-20 17:00:00                      72.0              6.0             0.0
# 2020-07-20 18:00:00                      71.0              6.0             0.0
# 2020-07-20 19:00:00                      70.0              3.0             0.0
# 2020-07-20 20:00:00                      70.0              3.0             0.0
# 2020-07-20 21:00:00                      70.0              0.0             0.0
# 2020-07-20 22:00:00                      69.0              0.0             0.0
# 2020-07-20 23:00:00                      69.0              0.0             0.0

# %% [markdown]
# Awesome now I have one big dataframe with the weather conditions and energy output at each hour. The dataframe spans from January 29, 2018 to July 20, 2020. Now I can begin exploring the data with this current dataframe I have.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.corr()
# Out:
#                            nexus_meter  inverter  HourlyAltimeterSetting  \
# nexus_meter                   1.000000  0.983593                0.043478
# inverter                      0.983593  1.000000                0.035830
# HourlyAltimeterSetting        0.043478  0.035830                1.000000
# HourlyDewPointTemperature     0.137505  0.146890               -0.435791
# HourlyDryBulbTemperature      0.394249  0.398156               -0.369664
# HourlyRelativeHumidity       -0.683752 -0.668699               -0.146621
# HourlySeaLevelPressure        0.024857  0.016747                0.996606
# HourlyStationPressure         0.043754  0.036099                0.999902
# HourlyVisibility              0.246685  0.241070                0.110607
# HourlyWetBulbTemperature      0.268081  0.273732               -0.410070
# HourlyWindSpeed               0.122774  0.116465               -0.225142
# cloud_coverage               -0.190532 -0.186083               -0.209996
#
#                            HourlyDewPointTemperature  \
# nexus_meter                                 0.137505
# inverter                                    0.146890
# HourlyAltimeterSetting                     -0.435791
# HourlyDewPointTemperature                   1.000000
# HourlyDryBulbTemperature                    0.925439
# HourlyRelativeHumidity                      0.083335
# HourlySeaLevelPressure                     -0.500612
# HourlyStationPressure                      -0.436110
# HourlyVisibility                            0.067361
# HourlyWetBulbTemperature                    0.979680
# HourlyWindSpeed                            -0.229555
# cloud_coverage                             -0.072182
#
#                            HourlyDryBulbTemperature  HourlyRelativeHumidity  \
# nexus_meter                                0.394249               -0.683752
# inverter                                   0.398156               -0.668699
# HourlyAltimeterSetting                    -0.369664               -0.146621
# HourlyDewPointTemperature                  0.925439                0.083335
# HourlyDryBulbTemperature                   1.000000               -0.293265
# HourlyRelativeHumidity                    -0.293265                1.000000
# HourlySeaLevelPressure                    -0.437464               -0.131009
# HourlyStationPressure                     -0.370165               -0.146274
# HourlyVisibility                           0.217518               -0.477629
# HourlyWetBulbTemperature                   0.980516               -0.109282
# HourlyWindSpeed                           -0.152838               -0.183543
# cloud_coverage                            -0.184591                0.326387
#
#                            HourlySeaLevelPressure  HourlyStationPressure  \
# nexus_meter                              0.024857               0.043754
# inverter                                 0.016747               0.036099
# HourlyAltimeterSetting                   0.996606               0.999902
# HourlyDewPointTemperature               -0.500612              -0.436110
# HourlyDryBulbTemperature                -0.437464              -0.370165
# HourlyRelativeHumidity                  -0.131009              -0.146274
# HourlySeaLevelPressure                   1.000000               0.996510
# HourlyStationPressure                    0.996510               1.000000
# HourlyVisibility                         0.091387               0.109122
# HourlyWetBulbTemperature                -0.477809              -0.410187
# HourlyWindSpeed                         -0.199106              -0.224820
# cloud_coverage                          -0.186235              -0.209775
#
#                            HourlyVisibility  HourlyWetBulbTemperature  \
# nexus_meter                        0.246685                  0.268081
# inverter                           0.241070                  0.273732
# HourlyAltimeterSetting             0.110607                 -0.410070
# HourlyDewPointTemperature          0.067361                  0.979680
# HourlyDryBulbTemperature           0.217518                  0.980516
# HourlyRelativeHumidity            -0.477629                 -0.109282
# HourlySeaLevelPressure             0.091387                 -0.477809
# HourlyStationPressure              0.109122                 -0.410187
# HourlyVisibility                   1.000000                  0.149927
# HourlyWetBulbTemperature           0.149927                  1.000000
# HourlyWindSpeed                    0.009741                 -0.194544
# cloud_coverage                    -0.385113                 -0.133133
#
#                            HourlyWindSpeed  cloud_coverage
# nexus_meter                       0.122774       -0.190532
# inverter                          0.116465       -0.186083
# HourlyAltimeterSetting           -0.225142       -0.209996
# HourlyDewPointTemperature        -0.229555       -0.072182
# HourlyDryBulbTemperature         -0.152838       -0.184591
# HourlyRelativeHumidity           -0.183543        0.326387
# HourlySeaLevelPressure           -0.199106       -0.186235
# HourlyStationPressure            -0.224820       -0.209775
# HourlyVisibility                  0.009741       -0.385113
# HourlyWetBulbTemperature         -0.194544       -0.133133
# HourlyWindSpeed                   1.000000        0.243294
# cloud_coverage                    0.243294        1.000000

# %% [markdown]
# DryBulbTemperature is the primary measure of temperature and largely correlated with WetBulbTemperature. For that reason i am going to drop WetBulbTemperature

# %%
df.drop('HourlyWetBulbTemperature', axis=1, inplace=True)

# %% [markdown]
# The feature that correlates most with energy production (nexus_meter) seems to be HourlyDryBulbTemperature, which is the air temperature at time of observation.

# %%
df['HourlyDryBulbTemperature'].plot(figsize=(8, 5))

# %% [markdown]
# As one would expect, temperature fluctuates with the time of year which can be seen from the overall trend of the plot. It also fluctuates with time of day as you can see from the little deviations throughout the time series.

# %% [markdown]
# For my MVP, I want to use weather conditions to predict energy output three hours in the future. In order to utilize traditional machine learning models, I need to structure the dataframe in a way that reflects this. So for a given row, the weather observations will be a three hour time lag compared to the energy output. I want to format a dataframe in this way, then i can begin working on an FSM.

# %%
weather_hourly['time'] = weather_hourly.index

# %%
df2 = pd.concat([hourly, weather_hourly.shift(3)], axis=1)

# %%
df.head(24)
# Out:
#                      nexus_meter  inverter  HourlyAltimeterSetting  \
# DATE
# 2018-01-29 00:00:00          NaN       NaN               30.342500
# 2018-01-29 01:00:00          NaN       NaN               30.340000
# 2018-01-29 02:00:00          NaN       NaN               30.330000
# 2018-01-29 03:00:00          NaN       NaN               30.330000
# 2018-01-29 04:00:00          NaN       NaN               30.330000
# 2018-01-29 05:00:00          NaN       NaN               30.340000
# 2018-01-29 06:00:00          NaN       NaN               30.360000
# 2018-01-29 07:00:00          NaN       NaN               30.370000
# 2018-01-29 08:00:00          NaN       NaN               30.373333
# 2018-01-29 09:00:00          NaN       NaN               30.400000
# 2018-01-29 10:00:00          NaN       NaN               30.410000
# 2018-01-29 11:00:00          NaN       NaN               30.400000
# 2018-01-29 12:00:00          NaN       NaN               30.390000
# 2018-01-29 13:00:00          NaN       NaN               30.380000
# 2018-01-29 14:00:00          NaN       NaN               30.390000
# 2018-01-29 15:00:00          NaN       NaN               30.395000
# 2018-01-29 16:00:00          NaN       NaN               30.420000
# 2018-01-29 17:00:00          NaN       NaN               30.433333
# 2018-01-29 18:00:00          NaN       NaN               30.460000
# 2018-01-29 19:00:00          NaN       NaN               30.465000
# 2018-01-29 20:00:00          NaN       NaN               30.470000
# 2018-01-29 21:00:00          NaN       NaN               30.470000
# 2018-01-29 22:00:00          NaN       NaN               30.480000
# 2018-01-29 23:00:00          NaN       NaN               30.480000
#
#                      HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# DATE
# 2018-01-29 00:00:00                  28.000000                 30.000000
# 2018-01-29 01:00:00                  28.000000                 30.000000
# 2018-01-29 02:00:00                  28.000000                 30.000000
# 2018-01-29 03:00:00                  28.000000                 30.000000
# 2018-01-29 04:00:00                  28.000000                 30.000000
# 2018-01-29 05:00:00                  27.000000                 30.000000
# 2018-01-29 06:00:00                  26.000000                 29.000000
# 2018-01-29 07:00:00                  25.000000                 28.250000
# 2018-01-29 08:00:00                  24.000000                 28.000000
# 2018-01-29 09:00:00                  23.000000                 29.000000
# 2018-01-29 10:00:00                  23.000000                 29.000000
# 2018-01-29 11:00:00                  23.000000                 29.000000
# 2018-01-29 12:00:00                  22.000000                 29.000000
# 2018-01-29 13:00:00                  20.000000                 29.000000
# 2018-01-29 14:00:00                  17.000000                 28.000000
# 2018-01-29 15:00:00                  16.500000                 27.500000
# 2018-01-29 16:00:00                  16.000000                 26.500000
# 2018-01-29 17:00:00                  16.333333                 25.666667
# 2018-01-29 18:00:00                  15.000000                 25.000000
# 2018-01-29 19:00:00                  14.500000                 24.500000
# 2018-01-29 20:00:00                  13.000000                 19.000000
# 2018-01-29 21:00:00                  15.000000                 19.000000
# 2018-01-29 22:00:00                  13.000000                 17.000000
# 2018-01-29 23:00:00                  13.000000                 17.000000
#
#                      HourlyRelativeHumidity  HourlySeaLevelPressure  \
# DATE
# 2018-01-29 00:00:00                   92.25                   30.36
# 2018-01-29 01:00:00                   92.00                   30.35
# 2018-01-29 02:00:00                   92.00                   30.34
# 2018-01-29 03:00:00                   92.00                   30.34
# 2018-01-29 04:00:00                   92.50                   30.35
# 2018-01-29 05:00:00                   88.00                   30.37
# 2018-01-29 06:00:00                   89.00                   30.38
# 2018-01-29 07:00:00                   86.75                   30.39
# 2018-01-29 08:00:00                   85.00                   30.41
# 2018-01-29 09:00:00                   78.00                   30.42
# 2018-01-29 10:00:00                   78.00                   30.44
# 2018-01-29 11:00:00                   78.00                   30.43
# 2018-01-29 12:00:00                   75.00                   30.42
# 2018-01-29 13:00:00                   69.00                   30.40
# 2018-01-29 14:00:00                   63.00                   30.42
# 2018-01-29 15:00:00                   63.00                   30.43
# 2018-01-29 16:00:00                   65.00                   30.45
# 2018-01-29 17:00:00                   68.00                   30.47
# 2018-01-29 18:00:00                   66.00                   30.49
# 2018-01-29 19:00:00                   65.50                   30.50
# 2018-01-29 20:00:00                   77.00                   30.50
# 2018-01-29 21:00:00                   84.00                   30.51
# 2018-01-29 22:00:00                   84.00                   30.52
# 2018-01-29 23:00:00                   84.00                   30.51
#
#                      HourlyStationPressure  HourlyVisibility  HourlyWindSpeed  \
# DATE
# 2018-01-29 00:00:00              29.512500          5.750000        14.250000
# 2018-01-29 01:00:00              29.510000          3.000000        10.000000
# 2018-01-29 02:00:00              29.500000          5.000000        13.000000
# 2018-01-29 03:00:00              29.500000          6.000000        13.000000
# 2018-01-29 04:00:00              29.500000          6.000000        10.500000
# 2018-01-29 05:00:00              29.510000         10.000000        14.000000
# 2018-01-29 06:00:00              29.530000          5.000000        16.000000
# 2018-01-29 07:00:00              29.540000          9.000000        14.500000
# 2018-01-29 08:00:00              29.543333          9.666667        17.000000
# 2018-01-29 09:00:00              29.570000         10.000000        15.000000
# 2018-01-29 10:00:00              29.580000          8.000000        17.000000
# 2018-01-29 11:00:00              29.570000          6.000000        18.000000
# 2018-01-29 12:00:00              29.560000         10.000000        16.000000
# 2018-01-29 13:00:00              29.550000         10.000000        22.000000
# 2018-01-29 14:00:00              29.560000         10.000000        20.000000
# 2018-01-29 15:00:00              29.565000         10.000000        17.500000
# 2018-01-29 16:00:00              29.590000         10.000000        17.000000
# 2018-01-29 17:00:00              29.603333         10.000000        14.333333
# 2018-01-29 18:00:00              29.630000         10.000000        15.000000
# 2018-01-29 19:00:00              29.635000         10.000000        14.500000
# 2018-01-29 20:00:00              29.640000         10.000000         6.000000
# 2018-01-29 21:00:00              29.640000         10.000000         6.000000
# 2018-01-29 22:00:00              29.650000         10.000000         6.000000
# 2018-01-29 23:00:00              29.650000         10.000000         5.000000
#
#                      cloud_coverage
# DATE
# 2018-01-29 00:00:00            80.0
# 2018-01-29 01:00:00            80.0
# 2018-01-29 02:00:00            80.0
# 2018-01-29 03:00:00            80.0
# 2018-01-29 04:00:00            80.0
# 2018-01-29 05:00:00            80.0
# 2018-01-29 06:00:00            80.0
# 2018-01-29 07:00:00            80.0
# 2018-01-29 08:00:00            80.0
# 2018-01-29 09:00:00            80.0
# 2018-01-29 10:00:00            80.0
# 2018-01-29 11:00:00            80.0
# 2018-01-29 12:00:00            80.0
# 2018-01-29 13:00:00            80.0
# 2018-01-29 14:00:00            80.0
# 2018-01-29 15:00:00            80.0
# 2018-01-29 16:00:00            80.0
# 2018-01-29 17:00:00            80.0
# 2018-01-29 18:00:00            80.0
# 2018-01-29 19:00:00            75.0
# 2018-01-29 20:00:00             0.0
# 2018-01-29 21:00:00             0.0
# 2018-01-29 22:00:00             0.0
# 2018-01-29 23:00:00             0.0

# %% [markdown]
# The first 24 obvservations in the dataframe do not contain energy data, so I will drop those rows.

# %%
df2.drop(df[:24].index, axis=0, inplace=True)

# %%
df2.head(24)
# Out:
#                      nexus_meter  inverter  HourlyAltimeterSetting  \
# DATE
# 2018-01-30 00:00:00        0.000      0.00                   30.47
# 2018-01-30 01:00:00        0.000      0.00                   30.48
# 2018-01-30 02:00:00        0.000      0.00                   30.48
# 2018-01-30 03:00:00        0.000      0.00                   30.46
# 2018-01-30 04:00:00        0.000      0.00                   30.47
# 2018-01-30 05:00:00        0.000      0.00                   30.47
# 2018-01-30 06:00:00        0.000      1.08                   30.46
# 2018-01-30 07:00:00        0.000     57.50                   30.45
# 2018-01-30 08:00:00        0.000      0.00                   30.47
# 2018-01-30 09:00:00        0.000      0.00                   30.50
# 2018-01-30 10:00:00      276.600    321.00                   30.48
# 2018-01-30 11:00:00    10128.000  10162.00                   30.53
# 2018-01-30 12:00:00    17570.000  17734.00                   30.52
# 2018-01-30 13:00:00    16156.000  16323.00                   30.48
# 2018-01-30 14:00:00    12779.000  12901.00                   30.45
# 2018-01-30 15:00:00     6430.000   6528.00                   30.42
# 2018-01-30 16:00:00     1404.900   1634.00                   30.37
# 2018-01-30 17:00:00      -33.111      0.00                   30.34
# 2018-01-30 18:00:00      -44.600      0.00                   30.30
# 2018-01-30 19:00:00      -43.800      0.00                   30.25
# 2018-01-30 20:00:00      -48.400      0.00                   30.25
# 2018-01-30 21:00:00      -43.500      0.00                   30.22
# 2018-01-30 22:00:00      -49.100      0.00                   30.18
# 2018-01-30 23:00:00      -52.500      0.00                   30.15
#
#                      HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# DATE
# 2018-01-30 00:00:00                       15.0                      19.0
# 2018-01-30 01:00:00                       13.0                      17.0
# 2018-01-30 02:00:00                       13.0                      17.0
# 2018-01-30 03:00:00                       14.0                      17.0
# 2018-01-30 04:00:00                       11.0                      15.0
# 2018-01-30 05:00:00                       11.0                      14.0
# 2018-01-30 06:00:00                       11.0                      14.0
# 2018-01-30 07:00:00                       10.0                      13.0
# 2018-01-30 08:00:00                       11.0                      14.0
# 2018-01-30 09:00:00                       11.0                      13.0
# 2018-01-30 10:00:00                       13.0                      16.0
# 2018-01-30 11:00:00                       13.0                      21.0
# 2018-01-30 12:00:00                       12.0                      23.0
# 2018-01-30 13:00:00                       12.0                      25.0
# 2018-01-30 14:00:00                       14.0                      27.0
# 2018-01-30 15:00:00                       16.0                      29.0
# 2018-01-30 16:00:00                       17.0                      31.0
# 2018-01-30 17:00:00                       17.0                      31.0
# 2018-01-30 18:00:00                       18.0                      32.0
# 2018-01-30 19:00:00                       19.0                      30.0
# 2018-01-30 20:00:00                       19.0                      30.0
# 2018-01-30 21:00:00                       20.0                      30.0
# 2018-01-30 22:00:00                       21.0                      30.0
# 2018-01-30 23:00:00                       21.0                      30.0
#
#                      HourlyRelativeHumidity  HourlySeaLevelPressure  \
# DATE
# 2018-01-30 00:00:00                    84.0                   30.51
# 2018-01-30 01:00:00                    84.0                   30.52
# 2018-01-30 02:00:00                    84.0                   30.51
# 2018-01-30 03:00:00                    88.0                   30.50
# 2018-01-30 04:00:00                    84.0                   30.50
# 2018-01-30 05:00:00                    88.0                   30.50
# 2018-01-30 06:00:00                    88.0                   30.49
# 2018-01-30 07:00:00                    88.0                   30.49
# 2018-01-30 08:00:00                    88.0                   30.51
# 2018-01-30 09:00:00                    92.0                   30.54
# 2018-01-30 10:00:00                    88.0                   30.52
# 2018-01-30 11:00:00                    71.0                   30.56
# 2018-01-30 12:00:00                    63.0                   30.55
# 2018-01-30 13:00:00                    58.0                   30.52
# 2018-01-30 14:00:00                    58.0                   30.49
# 2018-01-30 15:00:00                    58.0                   30.45
# 2018-01-30 16:00:00                    56.0                   30.40
# 2018-01-30 17:00:00                    56.0                   30.37
# 2018-01-30 18:00:00                    56.0                   30.34
# 2018-01-30 19:00:00                    64.0                   30.28
# 2018-01-30 20:00:00                    64.0                   30.28
# 2018-01-30 21:00:00                    66.0                   30.25
# 2018-01-30 22:00:00                    69.0                   30.22
# 2018-01-30 23:00:00                    69.0                   30.18
#
#                      HourlyStationPressure  HourlyVisibility  \
# DATE
# 2018-01-30 00:00:00                  29.64              10.0
# 2018-01-30 01:00:00                  29.65              10.0
# 2018-01-30 02:00:00                  29.65              10.0
# 2018-01-30 03:00:00                  29.63              10.0
# 2018-01-30 04:00:00                  29.64              10.0
# 2018-01-30 05:00:00                  29.64              10.0
# 2018-01-30 06:00:00                  29.63              10.0
# 2018-01-30 07:00:00                  29.62              10.0
# 2018-01-30 08:00:00                  29.64              10.0
# 2018-01-30 09:00:00                  29.67              10.0
# 2018-01-30 10:00:00                  29.65              10.0
# 2018-01-30 11:00:00                  29.70              10.0
# 2018-01-30 12:00:00                  29.69              10.0
# 2018-01-30 13:00:00                  29.65              10.0
# 2018-01-30 14:00:00                  29.62              10.0
# 2018-01-30 15:00:00                  29.59              10.0
# 2018-01-30 16:00:00                  29.54              10.0
# 2018-01-30 17:00:00                  29.51              10.0
# 2018-01-30 18:00:00                  29.47              10.0
# 2018-01-30 19:00:00                  29.42              10.0
# 2018-01-30 20:00:00                  29.42              10.0
# 2018-01-30 21:00:00                  29.39              10.0
# 2018-01-30 22:00:00                  29.36              10.0
# 2018-01-30 23:00:00                  29.33              10.0
#
#                      HourlyWetBulbTemperature  HourlyWindSpeed  \
# DATE
# 2018-01-30 00:00:00                      18.0              6.0
# 2018-01-30 01:00:00                      16.0              6.0
# 2018-01-30 02:00:00                      16.0              5.0
# 2018-01-30 03:00:00                      16.0              6.0
# 2018-01-30 04:00:00                      14.0              6.0
# 2018-01-30 05:00:00                      13.0              5.0
# 2018-01-30 06:00:00                      13.0              5.0
# 2018-01-30 07:00:00                      12.0              0.0
# 2018-01-30 08:00:00                      13.0              6.0
# 2018-01-30 09:00:00                      12.0              6.0
# 2018-01-30 10:00:00                      15.0              0.0
# 2018-01-30 11:00:00                      19.0              3.0
# 2018-01-30 12:00:00                      20.0              3.0
# 2018-01-30 13:00:00                      21.0              0.0
# 2018-01-30 14:00:00                      23.0              6.0
# 2018-01-30 15:00:00                      25.0              9.0
# 2018-01-30 16:00:00                      26.0              9.0
# 2018-01-30 17:00:00                      26.0             13.0
# 2018-01-30 18:00:00                      27.0             16.0
# 2018-01-30 19:00:00                      26.0             15.0
# 2018-01-30 20:00:00                      26.0             13.0
# 2018-01-30 21:00:00                      27.0             15.0
# 2018-01-30 22:00:00                      27.0             20.0
# 2018-01-30 23:00:00                      27.0             20.0
#
#                      cloud_coverage                time
# DATE
# 2018-01-30 00:00:00             0.0 2018-01-29 21:00:00
# 2018-01-30 01:00:00             0.0 2018-01-29 22:00:00
# 2018-01-30 02:00:00             0.0 2018-01-29 23:00:00
# 2018-01-30 03:00:00             0.0 2018-01-30 00:00:00
# 2018-01-30 04:00:00             0.0 2018-01-30 01:00:00
# 2018-01-30 05:00:00             0.0 2018-01-30 02:00:00
# 2018-01-30 06:00:00             0.0 2018-01-30 03:00:00
# 2018-01-30 07:00:00             0.0 2018-01-30 04:00:00
# 2018-01-30 08:00:00             0.0 2018-01-30 05:00:00
# 2018-01-30 09:00:00             0.0 2018-01-30 06:00:00
# 2018-01-30 10:00:00             0.0 2018-01-30 07:00:00
# 2018-01-30 11:00:00             0.0 2018-01-30 08:00:00
# 2018-01-30 12:00:00             0.0 2018-01-30 09:00:00
# 2018-01-30 13:00:00             0.0 2018-01-30 10:00:00
# 2018-01-30 14:00:00             0.0 2018-01-30 11:00:00
# 2018-01-30 15:00:00             0.0 2018-01-30 12:00:00
# 2018-01-30 16:00:00             0.0 2018-01-30 13:00:00
# 2018-01-30 17:00:00             0.0 2018-01-30 14:00:00
# 2018-01-30 18:00:00             0.0 2018-01-30 15:00:00
# 2018-01-30 19:00:00             0.0 2018-01-30 16:00:00
# 2018-01-30 20:00:00             0.0 2018-01-30 17:00:00
# 2018-01-30 21:00:00             0.0 2018-01-30 18:00:00
# 2018-01-30 22:00:00             0.0 2018-01-30 19:00:00
# 2018-01-30 23:00:00             0.0 2018-01-30 20:00:00

# %% [markdown]
# Perfect, now the energy output of each row corresponds to the weather observations three hours prior. Now that I know how to do this, I want to create a few functions that do the initial cleaning and formatting of the dataframes for me, so i can replicate the process above in other notebooks. The first one I want to create is a function that read's in all of the energy data files from the data/solar_output directory.

# %%
def energy_data():
    filelist = os.listdir('../data/solar_output')

    fl = ['../data/solar_output/' + str(f) for f in filelist]

    dfs = [pd.read_csv(f) for f in fl]

    big_df = pd.concat(dfs)

    big_df.columns = ['time', 'nexus_meter', 'inverter']

    big_df.drop([0,1], axis=0, inplace=True)

    big_df['time'] = pd.to_datetime(big_df['time'])

    big_df = big_df.sort_values('time')
    big_df.set_index('time', inplace=True)

    hourly = big_df.resample('H').sum()

    hourly = hourly['2018-01-30':]

    return hourly

# %% [markdown]
# The function above returns the hourly energy data in the correct format. It also subset for the dates that contained no data in early January of 2018. I leave a day of missing data to account for the time shift of weather data when merging the dataframes. The next funcion read's in the weather data and get's the first few columns. The subsequent functions will serve as processing steps for the weather dataframe

# %%
def weather_data():
    weather_cols = ['HourlyAltimeterSetting', 'HourlyDewPointTemperature', 'HourlyDryBulbTemperature',
    'HourlyRelativeHumidity', 'HourlySeaLevelPressure', 'HourlySkyConditions', 'HourlyStationPressure', 
    'HourlyVisibility', 'HourlyWindSpeed']
    df = pd.read_csv('../data/weather/weatherstation2.csv')

    df['DATE'] = pd.to_datetime(df['DATE'])
    df.set_index('DATE', inplace=True)

    cols_with_letter = columns_with_letter(df[weather_cols])

    for col in cols_with_letter:
        letter = letter_in_column(df[col])
        df[col] = remove_letter_from_column(df, col, value)

    df['cloud_coverage'] = cloud_coverage(df['HourlySkyConditions'])
    weather_cols.append('cloud_coverage')
    return df[weather_cols].drop('HourlySkyConditions', axis=1)

# %%
import string

# %%
def columns_with_letter(df):
    alph = string.ascii_lowercase
    cols = []
    for col in df.columns:
        for row in df[col].values:
            try:
                if row[-1].lower() in alph:
                    cols.append(col)
            except:
                pass
    return np.unique(cols)

# %%
def letter_in_column(col):
    alph = string.ascii_lowercase
    val = None
    for row in col.values:
        try:
            if row[-1].lower() in alph:
                val = row[-1]
        except:
            pass
    return val

# %%
def remove_letter_from_column(df, col, letter):
    lst = []
    for val in df[col].values:
        if letter in str(val):
            lst.append(val.replace(letter, ''))
        else:
            lst.append(val)
    return lst

# %%
def cloud_coverage(sky_conditions):
    clouds = []
    for val in sky_conditions.values:
        if type(val) == float:
            clouds.append(val)
        elif type(val) == str:
            v = val.split()
            if len(v) == 1:
                clouds.append(int(v[0][-1]))
            elif len(v) > 1:
                try:
                    clouds.append(int(v[-2][-1]))
                except:
                    clouds.append(int(v[-1][-1]))

    cloud_percent = [v if v==np.nan else ((v/10) * 100) for v in clouds]

    return cloud_percent

# %%
weather_function = weather_data()

# %%
weather_function.head()
# Out:
#                     HourlyAltimeterSetting HourlyDewPointTemperature  \
# DATE
# 2018-01-29 00:23:00                  30.34                        28
# 2018-01-29 00:42:00                  30.35                        28
# 2018-01-29 00:51:00                  30.34                        28
# 2018-01-29 00:53:00                  30.34                        28
# 2018-01-29 01:53:00                  30.34                        28
#
#                     HourlyDryBulbTemperature HourlyRelativeHumidity  \
# DATE
# 2018-01-29 00:23:00                       30                     92
# 2018-01-29 00:42:00                       30                     92
# 2018-01-29 00:51:00                       30                     93
# 2018-01-29 00:53:00                       30                     92
# 2018-01-29 01:53:00                       30                     92
#
#                     HourlySeaLevelPressure HourlyStationPressure  \
# DATE
# 2018-01-29 00:23:00                    NaN                 29.51
# 2018-01-29 00:42:00                    NaN                 29.52
# 2018-01-29 00:51:00                    NaN                 29.51
# 2018-01-29 00:53:00                  30.36                 29.51
# 2018-01-29 01:53:00                  30.35                 29.51
#
#                     HourlyVisibility HourlyWindSpeed  cloud_coverage
# DATE
# 2018-01-29 00:23:00             5.00              14            80.0
# 2018-01-29 00:42:00             6.00              13            80.0
# 2018-01-29 00:51:00             6.00              15            80.0
# 2018-01-29 00:53:00             6.00              15            80.0
# 2018-01-29 01:53:00             3.00              10            80.0

# %% [markdown]
# ## Functions summary
# - energy_data -> stores all energy files from data/solar_output directory in a single dataframe. Formats columns and set's index as date
# - columns_with_letter -> finds all columns in weather dataframe that contain extraneous letters
# - letter_in_column -> finds extraneous letter in column
# - remove_letter_from_column -> removes all instances of extraneous letter from column in dataframe
# - cloud_coverage -> calculates cloud coverage percentage from 'HourlySkyConditions' information
# - weather_data -> reads in weather station file from data/weather. Uses subsequent functions to format and process columns.
# The function that formats the weater dataframe is missing a few functionalities for a reason. I left the '*' values alone because I want to look into those more before I drop them from the dataframe permanently. I did not aggregate the time index to hourly or fill in missing values because I want to be able to experiment with various methods of doing that during model iterations. These functions provide the base dataframe for both hourly and weather data which I can manipulate and format how I see fit during modeling.
